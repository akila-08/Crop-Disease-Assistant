# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Samridhaa\OneDrive\Desktop\DL Package\plant_disease_multimodal_dataset.csv")
data
# Out:
#           N   P   K  temperature   humidity        ph    rainfall  \
# 0        90  42  43    20.879744  82.002744  6.502985  202.935536
# 1        90  42  43    20.879744  82.002744  6.502985  202.935536
# 2        90  42  43    20.879744  82.002744  6.502985  202.935536
# 3        90  42  43    20.879744  82.002744  6.502985  202.935536
# 4        90  42  43    20.879744  82.002744  6.502985  202.935536
# ...     ...  ..  ..          ...        ...       ...         ...
# 219995  104  18  30    23.603016  60.396475  6.779833  140.937041
# 219996  104  18  30    23.603016  60.396475  6.779833  140.937041
# 219997  104  18  30    23.603016  60.396475  6.779833  140.937041
# 219998  104  18  30    23.603016  60.396475  6.779833  140.937041
# 219999  104  18  30    23.603016  60.396475  6.779833  140.937041
#
#               Mapped Label                                         Image Path  \
# 0       Apple___Apple_scab  color\Apple___Apple_scab\00075aa8-d81a-4184-85...
# ...

# %%
data['Label'].unique()
# Out:
# array(['Apple___Apple_scab', 'Apple___Black_rot',
#        'Apple___Cedar_apple_rust', 'Apple___healthy',
#        'Blueberry___healthy', 'Cherry_(including_sour)___healthy',
#        'Cherry_(including_sour)___Powdery_mildew',
#        'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#        'Corn_(maize)___Common_rust_', 'Corn_(maize)___healthy',
#        'Corn_(maize)___Northern_Leaf_Blight', 'Grape___Black_rot',
#        'Grape___Esca_(Black_Measles)', 'Grape___healthy',
#        'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#        'Orange___Haunglongbing_(Citrus_greening)',
#        'Peach___Bacterial_spot', 'Peach___healthy',
#        'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy',
#        'Potato___Early_blight', 'Potato___healthy'], dtype=object)

# %%
# Count unique values in the 'label' column
label_counts = data['Label'].value_counts()

# Print each unique label and its count
for label, count in label_counts.items():
    print(f"Label: {label}, Count: {count}")
# Out:
# Label: Apple___Apple_scab, Count: 10000
# Label: Apple___Black_rot, Count: 10000
# Label: Potato___Early_blight, Count: 10000
# Label: Pepper,_bell___healthy, Count: 10000
# Label: Pepper,_bell___Bacterial_spot, Count: 10000
# Label: Peach___healthy, Count: 10000
# Label: Peach___Bacterial_spot, Count: 10000
# Label: Orange___Haunglongbing_(Citrus_greening), Count: 10000
# Label: Grape___Leaf_blight_(Isariopsis_Leaf_Spot), Count: 10000
# Label: Grape___healthy, Count: 10000
# Label: Grape___Esca_(Black_Measles), Count: 10000
# Label: Grape___Black_rot, Count: 10000
# Label: Corn_(maize)___Northern_Leaf_Blight, Count: 10000
# Label: Corn_(maize)___healthy, Count: 10000
# Label: Corn_(maize)___Common_rust_, Count: 10000
# Label: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, Count: 10000
# Label: Cherry_(including_sour)___Powdery_mildew, Count: 10000
# Label: Cherry_(including_sour)___healthy, Count: 10000
# Label: Blueberry___healthy, Count: 10000
# ...
